# %%
import pandas as pd


file_in = 'C:/Temp/ls_log.csv'

# Read a csv file
df = pd.read_csv(file_in, sep=',')
print(df.shape)

df
# Out:
# (55780, 27)
#                             date  \
# 0      2025-09-25T23:30:44+05:30
# 1      2025-09-25T23:29:01+05:30
# 2      2025-09-25T23:27:19+05:30
# 3      2025-09-25T23:26:49+05:30
# 4      2025-09-25T23:26:48+05:30
# ...                          ...
# 55775  2025-09-05T00:06:52+05:30
# 55776  2025-09-05T00:06:45+05:30
# 55777  2025-09-05T00:06:42+05:30
# 55778  2025-09-05T00:06:34+05:30
# 55779  2025-09-05T00:06:32+05:30
#
#                                               asset_name event  \
# 0                                        Tally Dashboard  View
# 1                                        Tally Dashboard  View
# 2                   2025 NME Dashboard (Nature Asia GA4)  View
# 3                                        Tally Dashboard  View
# 4                                        Tally Dashboard  View
# ...                                                  ...   ...
# 55775       [Kampagnen-Report] e.Med Herbstkampagne 2024  View
# ...
